# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("data/paris2024-athletes.csv", sep = ';')
df.head()
# Out:
#                     nom                                Lien vers la source  \
# 0                 "671"  https://olympics.com/fr/paris-2024/athlete/-67...
# 1  AABERG IVERSEN Sarah  https://olympics.com/fr/paris-2024/athlete/sar...
# 2         AARDAHL Maren  https://olympics.com/fr/paris-2024/athlete/mar...
# 3       AARONSON Paxten  https://olympics.com/fr/paris-2024/athlete/pax...
# 4           AARTS Laura  https://olympics.com/fr/paris-2024/athlete/lau...
#
#    Discipline Date de naissance                           Pays  Âge Fonction  \
# 0    Breaking          19/10/05  République populaire de Chine   18  Athlète
# 1    Handball          10/04/90                       Danemark   34  Athlète
# 2    Handball          02/03/94                        Norvège   30  Athlète
# 3    Football          26/08/03          États-Unis d'Amérique   21  Athlète
# 4  Water-polo          10/08/96                       Pays-Bas   28  Athlète
#
# ...

# %%
unique_values_list = df['Pays'].unique().tolist()   
print(unique_values_list)
# Out:
# ['République populaire de Chine', 'Danemark', 'Norvège', "États-Unis d'Amérique", 'Pays-Bas', 'Suède', 'Kazakhstan', 'Espagne', 'Israël', 'Italie', 'Qatar', 'Albanie', 'Chili', 'Équipe olympique des réfugiés', 'Türkiye', 'Égypte', 'République arabe syrienne', 'Serbie', 'Soudan', 'Maroc', 'Belgique', 'Ouzbékistan', "République islamique d'Iran", 'Singapour', 'Maldives', 'Azerbaïdjan', 'Canada', 'Ukraine', 'Tadjikistan', 'Japon', 'Sri Lanka', 'Inde', 'Autriche', 'Slovénie', 'Nigéria', 'Jordanie', 'France', 'Hongrie', 'Suisse', 'Allemagne', 'Guyana', 'Brésil', 'Libye', 'Kenya', 'Palestine', 'Arabie saoudite', 'Cuba', 'Guinée', 'Guinée équatoriale', 'Roumanie', 'Grèce', 'Australie', 'Bahreïn', 'Irlande', 'Indonésie', 'Togo', 'Lituanie', 'Algérie', 'Samoa', 'Porto Rico', 'Portugal', 'Mexique', 'Colombie', 'Pérou', 'Mauritanie', 'Niger', 'Iraq', "Côte d'Ivoire", 'Finlande', 'Trinité-et-Tobago', 'Kirghizistan', 'Oman', 'Émirats arabes unis', 'Yémen', 'Koweït', 'Pologne', 'Argentine', 'Angol
# ...

# %%
unique_values_nb = df['Pays'].nunique()
print(unique_values_nb)
# Out:
# 206

# %%
unique_values_list = df['Fonction'].unique().tolist()   
print(unique_values_list)
# Out:
# ['Athlète', 'Athlète Remplaçant', 'Athlète remplaçant']
